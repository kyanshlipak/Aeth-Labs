# %%
# %matplotlib ipympl 
#matplotlib interactive for IPython

#import libraries and functions
import pandas as pd
import math
import matplotlib.pyplot as plt # to make mpl faster
import matplotlib as mpl # to make mpl faster
import numpy as np #numpy for tons of stuff
import matplotlib.style as mplstyle
mpl.rcParams['path.simplify_threshold'] = 1.0 # to make mpl faster
mplstyle.use('fast') # to make mpl faster
import AlicatMFC as alicat #main python file to use functions from there
from scipy.signal import savgol_filter # savgol filter for smoothing


#customize plot font sizes
plt.rc('axes',titlesize=15)
plt.rc('xtick',labelsize=9)
plt.rc('ytick',labelsize=9)
plt.rc('legend',fontsize = 8)
plt.rc('figure',titlesize = 15)
plt.style.use('dark_background')

#create "mosaic" customizing grid layout. Semicolons separate rows
fig,axes = plt.subplot_mosaic("AB;CD")
fig.set_size_inches(16,10)
plt.tight_layout
plt.subplots_adjust(wspace =0.25,hspace = 0.55)
plt.ion()

def plotAll(variable,MAs,axis,smoothed,name):
    colors = ["red", "orange", "yellow", "green", "cyan", "blue", "pink", "magenta", "white", "tan"]
    if smoothed:
        axis.set_title(name + " " + variable + " smoothed")
        for i in range(len(MAs)):
            strName = MAs[i].at[0,"Serial number"]
            if len(MAs) == 8:
                colors[7] = "tan"
            axis.plot(savgol_filter(MAs[i][variable],20,3), label = strName,color = colors[i])
    else:
        axis.set_title(name + " " + variable)
        for i in range(len(MAs)):
            strName = MAs[i].at[0,"Serial number"]
            axis.plot(MAs[i][variable], label = strName,color = colors[i])
    axis.legend(loc = "upper left",fancybox = True,framealpha = 0.4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import os
import glob

directory9_30 = r"C:\Users\Kyan Shlipak\Downloads\9-1 switching sampling locations\9-30"
directory2_15 = r"C:\Users\Kyan Shlipak\Downloads\9-1 switching sampling locations\2-15"
directory3_14 = r"C:\Users\Kyan Shlipak\Downloads\9-1 switching sampling locations\3-14"
directory3_55 = r"C:\Users\Kyan Shlipak\Downloads\9-1 switching sampling locations\3-55"
 
swap9_30 = []
swap2_15 = []
swap3_14 = []
swap3_55 = []
    
def addToDir(dirr, arr):
    for path in glob.iglob(f'{dirr}/*.csv'):
        arr.append(pd.read_csv(path))
        
addToDir(directory9_30,swap9_30)
addToDir(directory2_15,swap2_15)
addToDir(directory3_14,swap3_14)
addToDir(directory3_55,swap3_55)

# %%
for ax in axes:
    axes[ax].clear()
    axes[ax].set_ylim([1500,4000])
axes["B"].set_xlim([10,50]) 

axes["A"].set_xlim([245,300]) 

plotAll("IR BC1",swap9_30,axes["A"],False, "Configuration 'A'")
plotAll("IR BC1",swap2_15,axes["B"],False, "Configuration 'B'")
plotAll("IR BC1",swap3_14,axes["C"],False, "Configuration 'A'")
plotAll("IR BC1",swap3_55,axes["D"],False, "Configuration 'B'")

# %%
import os
import glob

MA1 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0180_S0047_220808112600.csv")
MA2 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0245_S0134_220808112601.csv")
MA3 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0031_S0048_220808112601.csv")
MA4 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA200-0364_S0081_220808112600.csv")
firstTest = [MA1,MA2,MA3,MA4]

MA1b = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0180_S0050_220809115300.csv")
MA2b= pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0245_S0136_220809115259.csv")
MA3b= pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0031_S0050_220809115300.csv")
MA4b= pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA200-0364_S0083_220809115300.csv")
MA5b= pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA200-0354_S0078_220809115300.csv")
firstFullTest = [MA1b,MA2b,MA3b,MA4b,MA5b]

suspension5 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA200-0354_S0080_220817140901.csv")
suspension2 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0245_S0138_220817140900.csv")
suspension3 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0031_S0052_220817140901.csv")
suspension4 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA200-0364_S0085_220817140901.csv")
newPartResuspension = [suspension2,suspension3,suspension4,suspension5]

overnight1 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA200-0354_S0081_220817162900.csv")
overnight2 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0031_S0053_220817162900.csv")
overnight3 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA200-0364_S0086_220817163001.csv")
overnight4 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0180_S0055_220817162900.csv")
overnight5 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\MA350-0245_S0139_220817162901.csv")
overnightNewPartZeroTest = [overnight1,overnight2,overnight3,overnight4,overnight5]

switchingLocations21 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #2\MA200-0354_S0086_220823143100.csv")
switchingLocations23 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #2\MA200-0364_S0091_220823143059.csv")
switchingLocations22 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #2\MA350-0031_S0058_220823143200.csv")
switchingLocations25 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #2\MA350-0180_S0060_220823143300.csv")
switchingLocations24 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #2\MA350-0245_S0144_220823143105.csv")
switchingLocations2 = [switchingLocations21,switchingLocations23,switchingLocations24,switchingLocations25,switchingLocations22]

switchingLocations11 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #1\MA200-0354_S0084_220823093900.csv")
switchingLocations13 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #1\MA200-0364_S0089_220823093900.csv")
switchingLocations12 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #1\MA350-0031_S0056_220823093800.csv")
switchingLocations15 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #1\MA350-0180_S0058_220823093700.csv")
switchingLocations14 = pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\8-23 switching locations #1\MA350-0245_S0142_220823093800.csv")
switchingLocations1 = [switchingLocations11,switchingLocations13,switchingLocations14,switchingLocations15]

newRoom = [
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0188_S0099_420416092101.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0192_S0005_220831092100.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0194_S0075_220831092100.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0198_S0067_220831092101.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0287_S0152_580303092100.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0308_S0005_220831092100.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0319_S0005_220831092100.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0363_S0082_220831092100.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA200-0365_S0076_220831092100.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\Basecamp Download (7)\8-31 full test new room\MA350-0157_S0165_220831092100.csv")
]

swap12_13 = [
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\12_13_sootgentest\12-13\MA200-0416_S0005_221213100000.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\12_13_sootgentest\12-13\MA200-0418_S0004_221213095959.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\12_13_sootgentest\12-13\MA200-0419_S0005_221213100000.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\12_13_sootgentest\12-13\MA200-0421_S0004_221213100000.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\12_13_sootgentest\12-13\MA200-0417_S0004_221213100000.csv"),
    pd.read_csv(r"C:\Users\Kyan Shlipak\Downloads\12_13_sootgentest\12-13\MA200-0420_S0004_221213100000.csv"),
]


plotAll("IR BC1",swap12_13,axes["A"],True,"new Room")
plotAll("IR BCc",swap12_13,axes["B"],False,"new room")
plotAll("Internal temp (C)",swap12_13,axes["C"],False,"new room")


axes["A"].set_ylim([-4000,25000])
axes["B"].set_ylim([-4000,25000])
axes["A"].legend(loc = "upper left",fancybox = True,framealpha = 0.4)
axes["B"].legend(loc = "upper left",fancybox = True,framealpha = 0.4)

#axes["A"].set_xlim([100,280])
fig.canvas.draw()

# %%
axes["A"].clear()
axes["B"].clear()
axes["C"].clear()

# %%
axes["A"].set_ylim([0,30000])
axes["B"].set_ylim([0,30000])
# Out:
# (0.0, 30000.0)
